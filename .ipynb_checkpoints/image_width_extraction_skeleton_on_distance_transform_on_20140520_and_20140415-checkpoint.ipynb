# %%
import os
import numpy as np
import cv2
from skimage import io, feature, morphology, segmentation, measure, filters, exposure
from scipy.ndimage import distance_transform_edt
import matplotlib.pyplot as plt
from skimage.morphology import disk, dilation,  skeletonize
from skimage.filters import gaussian
from scipy.signal import convolve2d
from scipy import ndimage as ndi,ndimage
from sklearn.decomposition import PCA

# %%
# Define input image path and output folder
input_folder = r"C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\crop_image"
output_folder = r"C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel"

# %%
#funtion to split the images
def split_region(image, x, y, w, h, min_size, std_thresh):
    region = image[y:y+h, x:x+w]

    if w <= min_size or h <= min_size or is_homogeneous(region, std_thresh):
        return [(x, y, w, h)]

    hw, hh = w // 2, h // 2
    regions = []
    regions += split_region(image, x, y, hw, hh, min_size, std_thresh)
    regions += split_region(image, x + hw, y, w - hw, hh, min_size, std_thresh)
    regions += split_region(image, x, y + hh, hw, h - hh, min_size, std_thresh)
    regions += split_region(image, x + hw, y + hh, w - hw, h - hh, min_size, std_thresh)

    return regions

# %%
def moving_average(data, window_size=3):
    return np.convolve(data, np.ones(window_size)/window_size, mode='same')

# %%
#funtion for canny treshold
def score_thresholds(seg_img, sigma, low_t, high_t, target_regions=2):
    # Apply Canny edge detection with custom sigma and thresholds
    edges = feature.canny(seg_img, sigma=sigma, low_threshold=low_t, high_threshold=high_t)

    # Convert to uint8 for OpenCV operations
    edges_uint8 = (edges * 255).astype(np.uint8)
    inverted = cv2.bitwise_not(edges_uint8)

    # Custom function to split regions
    regions = split_region(inverted, 0, 0, seg_img.shape[1], seg_img.shape[0], min_size=16, std_thresh=15)

    # Score based on deviation from target number of regions
    return abs(len(regions) - target_regions), edges, regions

# %%
#funtion to determine the best kernel to close the gaps in the mask
def score_closing(binary_mask, kernel_size, target_regions=2):
    structure = np.ones((kernel_size, kernel_size), dtype=np.uint8)
    closed_mask = ndimage.binary_closing(binary_mask, structure=structure)

    # Label connected regions
    labeled, num_features = ndimage.label(closed_mask)
    
    # Score: absolute distance to desired number of objects
    score = abs(num_features - target_regions)

    return score, closed_mask, num_features

# %%
# Process each image
for filename in os.listdir(input_folder):
    if filename.endswith((".jpg", ".png", ".jpeg")):
        image_path = os.path.join(input_folder, filename)
        os.makedirs(output_folder, exist_ok=True)

        # Load and preprocess image
        img = io.imread(image_path)
        img_float = img.astype(np.float64)
        seg = (np.clip(((3 * img_float[:, :, 1]) - 0.001 * img_float[:, :, 0] - 0.001 * img_float[:, :, 2]), 0, 255)).astype(np.uint8)

        # Find best parameters for Canny
        best_score = float('inf')
        best_edges = None
        best_params = (0.0, 0.0, 0.0)

        for sigma in [1, 1.1, 1.2]:
            for low_t in np.arange(0.05, 0.3, 0.05):
                for high_t in np.arange(low_t + 0.05, low_t + 0.2, 0.05):
                    score, edges, regions = score_thresholds(seg, sigma, low_t, high_t)
                    if score < best_score:
                        best_score = score
                        best_edges = edges
                        best_params = (sigma, low_t, high_t)

        # Use best parameters for final Canny
        sigma, low_t, high_t = best_params
        edge_canny = feature.canny(seg, sigma=sigma, low_threshold=low_t, high_threshold=high_t).astype(np.uint8)

        # Apply closing with best kernel
        best_score = float('inf')
        best_mask = None
        best_kernel = 1
        for k in range(3, 25, 2):
            score, result_mask, num_regions = score_closing(edge_canny, k)
            if score < best_score:
                best_score = score
                best_mask = result_mask
                best_kernel = k

        object_mask = (best_mask > 0).astype(np.uint8)
        smoothed_mask = ndimage.binary_closing(object_mask, structure=np.ones((best_kernel, best_kernel))).astype(np.uint8)

        contours, _ = cv2.findContours(smoothed_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Step 1: Find largest contour
        largest_contour = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Step 2: Add padding and crop region
        pad = 40
        x1 = max(x - pad, 0)
        y1 = max(y - pad, 0)
        x2 = min(x + w + pad, object_mask.shape[1])
        y2 = min(y + h + pad, object_mask.shape[0])

        # Step 3: Ensure mask and image have the same size
        if object_mask.shape[:2] != img.shape[:2]:
            object_mask = cv2.resize(object_mask, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)

        # Step 4: Crop both mask and image
        cropped_mask = object_mask[y1:y2, x1:x2]
        cropped_image = img[y1:y2, x1:x2] if len(img.shape) == 3 else img[y1:y2, x1:x2]

        # Step 5: Resize both to a fixed width (scale proportionally)
        scale = 1000 / max(cropped_mask.shape)
        resized_mask = cv2.resize(cropped_mask, None, fx=scale, fy=scale, interpolation=cv2.INTER_NEAREST)

        # Step 6: Get non-zero coordinates from mask for PCA
        ys, xs = np.nonzero(resized_mask)
        coords = np.column_stack((xs, ys))

        # Step 7: PCA to get orientation
        pca = PCA(n_components=2)
        pca.fit(coords)
        angle_rad = np.arctan2(pca.components_[0, 1], pca.components_[0, 0])
        angle_deg = np.degrees(angle_rad)

        # Normalize angle to align vertically
        if angle_deg < -90:
            angle_deg += 180
        elif angle_deg > 90:
            angle_deg -= 180
        angle_to_rotate = angle_deg + 90

        # Step 8: Rotate both image and mask, expanding canvas
        (h, w) = resized_mask.shape
        center = (w // 2, h // 2)
        M = cv2.getRotationMatrix2D(center, angle_to_rotate, 1.0)

        cos = np.abs(M[0, 0])
        sin = np.abs(M[0, 1])
        new_w = int((h * sin) + (w * cos))
        new_h = int((h * cos) + (w * sin))

        M[0, 2] += (new_w - w) // 2
        M[1, 2] += (new_h - h) // 2

        rotated_mask = cv2.warpAffine(resized_mask, M, (new_w, new_h), flags=cv2.INTER_NEAREST, borderValue=0)

        # Resize to final height of 1000
        final_height = 1000
        final_scale = final_height / rotated_mask.shape[0]
        rotated_mask = cv2.resize(rotated_mask, None, fx=final_scale, fy=final_scale, interpolation=cv2.INTER_NEAREST)

        # Find best kernel size for closing (again, optional)
        best_score = float('inf')
        best_kernel = 3
        for k in range(3, 20, 2):
            score, result_mask, num_regions = score_closing(rotated_mask, k)
            if score < best_score:
                best_score = score
                best_mask = result_mask
                best_kernel = k

        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (best_kernel, best_kernel))
        mask_clean = cv2.morphologyEx(rotated_mask, cv2.MORPH_OPEN, kernel, iterations=1)
        mask_clean = cv2.morphologyEx(mask_clean, cv2.MORPH_CLOSE, kernel, iterations=2)

        # Step 9: Distance transform + skeleton
        bool_mask = rotated_mask > 0
        skeleton = morphology.skeletonize(mask_clean ).astype(np.float64)
        binary_mask_uint8 = (bool_mask * 255).astype(np.uint8)
        dist_transform = cv2.distanceTransform(binary_mask_uint8, cv2.DIST_L2, 5).astype(np.float32)
        new_object = dist_transform * skeleton
        full_width_map = new_object * 2

        # Extract row-wise max widths
        row_max_widths = []
        for y in range(full_width_map.shape[0]):
            x_indices = np.where(full_width_map[y] > 0)[0]
            if len(x_indices) > 0:
                widths = full_width_map[y, x_indices]
                row_max_widths.append(np.max(widths))

        smoothed_data = np.insert(row_max_widths, 0, 0)
        iterations = 10
        for i in range(iterations):
            smoothed_data = np.insert(smoothed_data, 0, 0)
            smoothed_data = moving_average(smoothed_data, window_size=5)#to extract all the width stop the next wow
        smoothed_data = smoothed_data[:200]

        # Step 13: Save to file
        output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_widths.txt")
        with open(output_file, "w") as file:
            for width in smoothed_data:
                file.write(f"{width}\n")

        print(f"Widths saved to {output_file}")
# Out:
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_000_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_001_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_002_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_003_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_004_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_005_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_006_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_007_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_008_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_009_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_010_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_011_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_012_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_013_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_014_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_015_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_016_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_017_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_018_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_019_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_020_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_021_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_022_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_023_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_024_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_025_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_026_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_027_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_028_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_029_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_030_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_031_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_032_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_033_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_034_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_035_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_036_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_037_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_038_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_039_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_040_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_041_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_042_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_043_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_044_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_045_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_046_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_047_widths.txt
# C:\Users\Paolo\AppData\Local\Temp\ipykernel_82548\3641086915.py:134: RuntimeWarning: invalid value encountered in cast
#   tip_widths_subset = (tip_widths[first_valid_index:end_index]).astype(int)
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_048_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_049_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_050_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_051_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_052_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_053_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_054_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_055_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_056_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_057_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_058_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_059_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_060_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_061_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_062_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_063_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_064_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_065_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_066_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_067_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_068_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_069_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_070_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_071_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_072_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_073_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_074_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_075_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_076_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_077_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_078_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_079_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_080_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_081_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_082_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_083_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_084_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_085_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_086_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_087_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_088_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_089_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_090_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_091_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_092_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_093_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_094_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_095_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_096_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_097_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_098_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_099_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_100_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_101_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_102_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_103_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_104_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_105_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_106_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_107_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_108_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_109_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_110_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_111_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_112_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_113_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_114_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_115_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_116_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_117_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_118_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_119_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_120_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_121_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_122_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_123_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_124_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_125_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_126_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_127_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_128_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_129_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_130_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_131_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_132_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_133_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_134_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_135_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_136_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_137_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_138_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_139_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_140_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_141_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_142_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_143_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_144_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_145_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_146_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_147_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_148_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_149_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_150_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_151_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_152_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_153_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_154_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_155_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_156_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_157_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_158_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_159_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_160_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_161_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_162_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_163_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_164_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_165_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_166_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_167_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_168_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_169_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_170_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_171_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_172_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_173_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_174_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_175_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_176_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_177_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_178_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_179_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_180_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_181_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_182_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_183_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_184_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_185_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_186_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_187_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_188_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_189_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_190_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_191_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_192_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_193_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_194_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_195_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_196_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_197_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_198_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_199_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_200_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_201_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_202_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_203_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_204_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_205_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_206_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_207_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_208_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_209_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_210_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_211_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_212_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_213_widths.txt
# C:\Users\Paolo\AppData\Local\Temp\ipykernel_82548\3641086915.py:134: RuntimeWarning: invalid value encountered in cast
#   tip_widths_subset = (tip_widths[first_valid_index:end_index]).astype(int)
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_214_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_215_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_216_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_217_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_218_widths.txt
# C:\Users\Paolo\AppData\Local\Temp\ipykernel_82548\3641086915.py:134: RuntimeWarning: invalid value encountered in cast
#   tip_widths_subset = (tip_widths[first_valid_index:end_index]).astype(int)
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_219_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_220_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_221_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_222_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_223_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_224_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_225_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_226_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_227_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_228_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_229_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_230_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_231_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_232_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_233_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_234_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_235_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_236_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_237_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_238_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_239_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_240_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_241_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_242_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_243_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_244_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_245_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_246_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_247_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_248_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_249_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_250_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_251_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_252_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_253_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_254_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_255_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_256_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_257_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_258_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_259_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_260_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_261_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_262_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_263_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_264_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_265_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_266_widths.txt
# Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_dis_x_skel\cropped_cucumber_267_widths.txt
