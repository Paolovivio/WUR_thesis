# %%
import os
import re
import numpy as np
import cv2
import time
from skimage import io, feature, morphology, segmentation, measure, filters, exposure
from scipy.ndimage import distance_transform_edt
import matplotlib.pyplot as plt
from skimage.morphology import disk, dilation,  skeletonize
from skimage.filters import gaussian
from scipy.signal import convolve2d, savgol_filter
from scipy import ndimage as ndi,ndimage
from sklearn.decomposition import PCA

# %%
# Define input image path and output folder
input_folder = r"C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\segmented_with_SAM"
output_folder = r"C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM"
output_folder_timer =r"C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415"

# %%
#funtion to split the images
def split_region(image, x, y, w, h, min_size, std_thresh):
    region = image[y:y+h, x:x+w]

    if w <= min_size or h <= min_size or is_homogeneous(region, std_thresh):
        return [(x, y, w, h)]

    hw, hh = w // 2, h // 2
    regions = []
    regions += split_region(image, x, y, hw, hh, min_size, std_thresh)
    regions += split_region(image, x + hw, y, w - hw, hh, min_size, std_thresh)
    regions += split_region(image, x, y + hh, hw, h - hh, min_size, std_thresh)
    regions += split_region(image, x + hw, y + hh, w - hw, h - hh, min_size, std_thresh)

    return regions

# %%
def moving_average(data, window_size=3):
    return np.convolve(data, np.ones(window_size)/window_size, mode='same')

# %%
def score_closing(binary_mask, kernel_size, target_regions=2):
    structure = np.ones((kernel_size, kernel_size), dtype=np.uint8)
    closed_mask = ndimage.binary_closing(binary_mask, structure=structure)

    # Label connected regions
    labeled, num_features = ndimage.label(closed_mask)
    
    # Score: absolute distance to desired number of objects
    score = abs(num_features - target_regions)

    return score, closed_mask, num_features

# %%
def extract_number(filename):
    # Extract number from "download(43).png"
    match = re.search(r'\((\d+)\)', filename)
    return int(match.group(1)) if match else -1

# %%
# Get sorted list of PNG files based on the number inside parentheses
sorted_files = sorted(
    [f for f in os.listdir(input_folder) if f.endswith((".png", ".jpg", ".jpeg"))],
    key=extract_number
)

# %%
processing_times = []  # To store (filename, processing_time)

# Process all images
for filename in sorted_files:
    start_time = time.time()  # Start timing for this image

    image_path = os.path.join(input_folder, filename)
    os.makedirs(output_folder, exist_ok=True)

    # Load image
    img = io.imread(image_path)

    # Pad image
    padded_image = cv2.copyMakeBorder(
        img,
        top=40, bottom=40, left=40, right=40,
        borderType=cv2.BORDER_CONSTANT,
        value=[0, 0, 0]
    )

    # Convert to grayscale
    padded_mask = cv2.cvtColor(padded_image, cv2.COLOR_RGB2GRAY)

    # Find coordinates for PCA
    ys, xs = np.nonzero(padded_mask)
    coords = np.column_stack((xs, ys))
    pca = PCA(n_components=2)
    pca.fit(coords)

    # PCA angle to rotate
    angle_rad = np.arctan2(pca.components_[0, 1], pca.components_[0, 0])
    angle_deg = np.degrees(angle_rad)
    if angle_deg < -90:
        angle_deg += 180
    elif angle_deg > 90:
        angle_deg -= 180
    angle_to_rotate = angle_deg + 90

    # Rotate image
    (h, w) = padded_mask.shape
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle_to_rotate, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    new_w = int((h * sin) + (w * cos))
    new_h = int((h * cos) + (w * sin))
    M[0, 2] += (new_w - w) // 2
    M[1, 2] += (new_h - h) // 2

    rotated_mask = cv2.warpAffine(
        padded_mask, M, (new_w, new_h),
        flags=cv2.INTER_NEAREST, borderValue=0
    )

    # Normalize mask
    scale = 1000 / max(rotated_mask.shape)
    resized_mask = cv2.resize(rotated_mask, None, fx=scale, fy=scale, interpolation=cv2.INTER_NEAREST)

    # Find best kernel size for closing
    best_score = float('inf')
    best_kernel = 3
    for k in range(3, 20, 2):  # Odd sizes only
        score, result_mask, num_regions = score_closing(resized_mask, k)
        if score < best_score:
            best_score = score
            best_mask = result_mask
            best_kernel = k

    # Apply best kernel for morphological cleaning
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (best_kernel, best_kernel))
    mask_clean = cv2.morphologyEx(resized_mask, cv2.MORPH_OPEN, kernel, iterations=1)
    mask_clean = cv2.morphologyEx(mask_clean, cv2.MORPH_CLOSE, kernel, iterations=2)

    # Convert to uint8 for distance transform
    binary_mask_uint8 = (mask_clean * 255).astype(np.uint8)

    # Distance transform
    dist_transform = cv2.distanceTransform(binary_mask_uint8, cv2.DIST_L2, 5)

    # Skeletonize
    skeleton = skeletonize(mask_clean).astype(np.float32)

    # Multiply to get width map
    new_object = dist_transform * skeleton

    # Get first 200 non-zero integer values
    full_width = new_object * 2
    row_max_widths = []
    for y in range(full_width.shape[0]):
        x_indices = np.where(full_width[y] > 0)[0]
        if len(x_indices) > 0:
            widths = full_width[y, x_indices]
            row_max_widths.append(np.max(widths))
    smoothed_data = np.insert(row_max_widths, 0, 0)        
    iterations = 10
    for i in range(iterations):
        smoothed_data = np.insert(smoothed_data, 0, 0)
        smoothed_data = moving_average(smoothed_data, window_size=5)
    smoothed_data = smoothed_data[:200]

    # Save widths to file
    output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_widths.txt")
    with open(output_file, "w") as file:
        for width in smoothed_data:
            file.write(f"{width}\n")

    # Stop timing for this image
    elapsed_time = time.time() - start_time
    processing_times.append((filename, elapsed_time))

    print(f"Processed {filename} in {elapsed_time:.2f} seconds. Widths saved to {output_file}")

# Save all processing times to file
times_file = os.path.join(output_folder, "processing_times_SAM.txt")
with open(times_file, "w") as f:
    for fname, t in processing_times:
        f.write(f"{fname}: {t:.4f} seconds\n")

print(f"Processing times saved to {times_file}")
# Out:
# Processed download(170.png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(170_widths.txt
# Processed download(0).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(0)_widths.txt
# Processed download(1).png in 0.55 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(1)_widths.txt
# Processed download(2).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(2)_widths.txt
# Processed download(3).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(3)_widths.txt
# Processed download(4).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(4)_widths.txt
# Processed download(5).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(5)_widths.txt
# Processed download(6).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(6)_widths.txt
# Processed download(7).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(7)_widths.txt
# Processed download(8).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(8)_widths.txt
# Processed download(9).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(9)_widths.txt
# Processed download(10).png in 0.59 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(10)_widths.txt
# Processed download(11).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(11)_widths.txt
# Processed download(12).png in 1.02 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(12)_widths.txt
# Processed download(13).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(13)_widths.txt
# Processed download(14).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(14)_widths.txt
# Processed download(15).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(15)_widths.txt
# Processed download(16).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(16)_widths.txt
# Processed download(17).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(17)_widths.txt
# Processed download(18).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(18)_widths.txt
# Processed download(19).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(19)_widths.txt
# Processed download(20).png in 0.71 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(20)_widths.txt
# Processed download(21).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(21)_widths.txt
# Processed download(22).png in 0.55 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(22)_widths.txt
# Processed download(23).png in 1.00 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(23)_widths.txt
# Processed download(24).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(24)_widths.txt
# Processed download(25).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(25)_widths.txt
# Processed download(26).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(26)_widths.txt
# Processed download(27).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(27)_widths.txt
# Processed download(28).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(28)_widths.txt
# Processed download(29).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(29)_widths.txt
# Processed download(30).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(30)_widths.txt
# Processed download(31).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(31)_widths.txt
# Processed download(32).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(32)_widths.txt
# Processed download(33).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(33)_widths.txt
# Processed download(34).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(34)_widths.txt
# Processed download(35).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(35)_widths.txt
# Processed download(36).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(36)_widths.txt
# Processed download(37).png in 0.49 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(37)_widths.txt
# Processed download(38).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(38)_widths.txt
# Processed download(39).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(39)_widths.txt
# Processed download(40).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(40)_widths.txt
# Processed download(41).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(41)_widths.txt
# Processed download(42).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(42)_widths.txt
# Processed download(43).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(43)_widths.txt
# Processed download(44).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(44)_widths.txt
# Processed download(45).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(45)_widths.txt
# Processed download(46).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(46)_widths.txt
# Processed download(47).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(47)_widths.txt
# Processed download(48).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(48)_widths.txt
# Processed download(49).png in 0.74 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(49)_widths.txt
# Processed download(50).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(50)_widths.txt
# Processed download(51).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(51)_widths.txt
# Processed download(52).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(52)_widths.txt
# Processed download(53).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(53)_widths.txt
# Processed download(54).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(54)_widths.txt
# Processed download(55).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(55)_widths.txt
# Processed download(56).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(56)_widths.txt
# Processed download(57).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(57)_widths.txt
# Processed download(58).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(58)_widths.txt
# Processed download(59).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(59)_widths.txt
# Processed download(60).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(60)_widths.txt
# Processed download(61).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(61)_widths.txt
# Processed download(62).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(62)_widths.txt
# Processed download(63).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(63)_widths.txt
# Processed download(64).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(64)_widths.txt
# Processed download(65).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(65)_widths.txt
# Processed download(66).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(66)_widths.txt
# Processed download(67).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(67)_widths.txt
# Processed download(68).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(68)_widths.txt
# Processed download(69).png in 0.83 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(69)_widths.txt
# Processed download(70).png in 0.47 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(70)_widths.txt
# Processed download(71).png in 0.49 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(71)_widths.txt
# Processed download(72).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(72)_widths.txt
# Processed download(73).png in 0.93 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(73)_widths.txt
# Processed download(74).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(74)_widths.txt
# Processed download(75).png in 0.83 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(75)_widths.txt
# Processed download(76).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(76)_widths.txt
# Processed download(77).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(77)_widths.txt
# Processed download(78).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(78)_widths.txt
# Processed download(79).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(79)_widths.txt
# Processed download(80).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(80)_widths.txt
# Processed download(81).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(81)_widths.txt
# Processed download(82).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(82)_widths.txt
# Processed download(83).png in 0.84 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(83)_widths.txt
# Processed download(84).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(84)_widths.txt
# Processed download(85).png in 0.80 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(85)_widths.txt
# Processed download(86).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(86)_widths.txt
# Processed download(87).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(87)_widths.txt
# Processed download(88).png in 0.82 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(88)_widths.txt
# Processed download(89).png in 0.59 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(89)_widths.txt
# Processed download(90).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(90)_widths.txt
# Processed download(91).png in 0.79 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(91)_widths.txt
# Processed download(92).png in 0.82 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(92)_widths.txt
# Processed download(93).png in 0.67 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(93)_widths.txt
# Processed download(94).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(94)_widths.txt
# Processed download(95).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(95)_widths.txt
# Processed download(96).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(96)_widths.txt
# Processed download(97).png in 0.83 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(97)_widths.txt
# Processed download(98).png in 0.67 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(98)_widths.txt
# Processed download(99).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(99)_widths.txt
# Processed download(100).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(100)_widths.txt
# Processed download(101).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(101)_widths.txt
# Processed download(102).png in 0.99 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(102)_widths.txt
# Processed download(103).png in 0.88 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(103)_widths.txt
# Processed download(104).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(104)_widths.txt
# Processed download(105).png in 0.98 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(105)_widths.txt
# Processed download(106).png in 0.93 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(106)_widths.txt
# Processed download(107).png in 0.55 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(107)_widths.txt
# Processed download(108).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(108)_widths.txt
# Processed download(109).png in 0.59 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(109)_widths.txt
# Processed download(110).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(110)_widths.txt
# Processed download(111).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(111)_widths.txt
# Processed download(112).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(112)_widths.txt
# Processed download(113).png in 0.93 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(113)_widths.txt
# Processed download(114).png in 0.77 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(114)_widths.txt
# Processed download(115).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(115)_widths.txt
# Processed download(116).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(116)_widths.txt
# Processed download(117).png in 1.02 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(117)_widths.txt
# Processed download(118).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(118)_widths.txt
# Processed download(119).png in 0.82 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(119)_widths.txt
# Processed download(120).png in 1.05 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(120)_widths.txt
# Processed download(121).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(121)_widths.txt
# Processed download(122).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(122)_widths.txt
# Processed download(123).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(123)_widths.txt
# Processed download(124).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(124)_widths.txt
# Processed download(125).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(125)_widths.txt
# Processed download(126).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(126)_widths.txt
# Processed download(127).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(127)_widths.txt
# Processed download(128).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(128)_widths.txt
# Processed download(129).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(129)_widths.txt
# Processed download(130).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(130)_widths.txt
# Processed download(131).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(131)_widths.txt
# Processed download(132).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(132)_widths.txt
# Processed download(133).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(133)_widths.txt
# Processed download(134).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(134)_widths.txt
# Processed download(135).png in 0.71 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(135)_widths.txt
# Processed download(136).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(136)_widths.txt
# Processed download(137).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(137)_widths.txt
# Processed download(138).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(138)_widths.txt
# Processed download(139).png in 0.71 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(139)_widths.txt
# Processed download(140).png in 0.77 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(140)_widths.txt
# Processed download(141).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(141)_widths.txt
# Processed download(142).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(142)_widths.txt
# Processed download(143).png in 0.90 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(143)_widths.txt
# Processed download(144).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(144)_widths.txt
# Processed download(145).png in 1.24 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(145)_widths.txt
# Processed download(146).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(146)_widths.txt
# Processed download(147).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(147)_widths.txt
# Processed download(148).png in 0.59 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(148)_widths.txt
# Processed download(149).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(149)_widths.txt
# Processed download(150).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(150)_widths.txt
# Processed download(151).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(151)_widths.txt
# Processed download(152).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(152)_widths.txt
# Processed download(153).png in 0.91 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(153)_widths.txt
# Processed download(154).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(154)_widths.txt
# Processed download(155).png in 0.63 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(155)_widths.txt
# Processed download(156).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(156)_widths.txt
# Processed download(157).png in 0.67 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(157)_widths.txt
# Processed download(158).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(158)_widths.txt
# Processed download(159).png in 0.67 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(159)_widths.txt
# Processed download(160).png in 0.53 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(160)_widths.txt
# Processed download(161).png in 0.71 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(161)_widths.txt
# Processed download(162).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(162)_widths.txt
# Processed download(163).png in 0.73 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(163)_widths.txt
# Processed download(164).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(164)_widths.txt
# Processed download(165).png in 1.02 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(165)_widths.txt
# Processed download(166).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(166)_widths.txt
# Processed download(167).png in 0.67 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(167)_widths.txt
# Processed download(168).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(168)_widths.txt
# Processed download(169).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(169)_widths.txt
# Processed download(171).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(171)_widths.txt
# Processed download(172).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(172)_widths.txt
# Processed download(173).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(173)_widths.txt
# Processed download(174).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(174)_widths.txt
# Processed download(175).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(175)_widths.txt
# Processed download(176).png in 0.71 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(176)_widths.txt
# Processed download(177).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(177)_widths.txt
# Processed download(178).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(178)_widths.txt
# Processed download(179).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(179)_widths.txt
# Processed download(180).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(180)_widths.txt
# Processed download(181).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(181)_widths.txt
# Processed download(182).png in 0.54 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(182)_widths.txt
# Processed download(183).png in 0.74 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(183)_widths.txt
# Processed download(184).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(184)_widths.txt
# Processed download(185).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(185)_widths.txt
# Processed download(186).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(186)_widths.txt
# Processed download(187).png in 0.73 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(187)_widths.txt
# Processed download(188).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(188)_widths.txt
# Processed download(189).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(189)_widths.txt
# Processed download(190).png in 0.74 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(190)_widths.txt
# Processed download(191).png in 0.82 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(191)_widths.txt
# Processed download(192).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(192)_widths.txt
# Processed download(193).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(193)_widths.txt
# Processed download(194).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(194)_widths.txt
# Processed download(195).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(195)_widths.txt
# Processed download(196).png in 0.47 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(196)_widths.txt
# Processed download(197).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(197)_widths.txt
# Processed download(198).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(198)_widths.txt
# Processed download(199).png in 0.73 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(199)_widths.txt
# Processed download(200).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(200)_widths.txt
# Processed download(201).png in 0.69 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(201)_widths.txt
# Processed download(202).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(202)_widths.txt
# Processed download(203).png in 0.89 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(203)_widths.txt
# Processed download(204).png in 0.76 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(204)_widths.txt
# Processed download(205).png in 0.82 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(205)_widths.txt
# Processed download(206).png in 0.68 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(206)_widths.txt
# Processed download(207).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(207)_widths.txt
# Processed download(208).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(208)_widths.txt
# Processed download(209).png in 0.93 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(209)_widths.txt
# Processed download(210).png in 1.12 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(210)_widths.txt
# Processed download(211).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(211)_widths.txt
# Processed download(212).png in 0.93 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(212)_widths.txt
# Processed download(213).png in 0.79 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(213)_widths.txt
# Processed download(214).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(214)_widths.txt
# Processed download(215).png in 0.84 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(215)_widths.txt
# Processed download(216).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(216)_widths.txt
# Processed download(217).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(217)_widths.txt
# Processed download(218).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(218)_widths.txt
# Processed download(219).png in 0.85 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(219)_widths.txt
# Processed download(220).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(220)_widths.txt
# Processed download(221).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(221)_widths.txt
# Processed download(222).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(222)_widths.txt
# Processed download(223).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(223)_widths.txt
# Processed download(224).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(224)_widths.txt
# Processed download(225).png in 0.55 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(225)_widths.txt
# Processed download(226).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(226)_widths.txt
# Processed download(227).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(227)_widths.txt
# Processed download(228).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(228)_widths.txt
# Processed download(229).png in 0.44 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(229)_widths.txt
# Processed download(230).png in 0.46 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(230)_widths.txt
# Processed download(231).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(231)_widths.txt
# Processed download(232).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(232)_widths.txt
# Processed download(233).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(233)_widths.txt
# Processed download(234).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(234)_widths.txt
# Processed download(235).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(235)_widths.txt
# Processed download(236).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(236)_widths.txt
# Processed download(237).png in 0.75 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(237)_widths.txt
# Processed download(238).png in 0.81 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(238)_widths.txt
# Processed download(239).png in 0.49 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(239)_widths.txt
# Processed download(240).png in 0.62 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(240)_widths.txt
# Processed download(241).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(241)_widths.txt
# Processed download(242).png in 0.60 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(242)_widths.txt
# Processed download(243).png in 0.47 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(243)_widths.txt
# Processed download(244).png in 0.78 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(244)_widths.txt
# Processed download(245).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(245)_widths.txt
# Processed download(246).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(246)_widths.txt
# Processed download(247).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(247)_widths.txt
# Processed download(248).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(248)_widths.txt
# Processed download(249).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(249)_widths.txt
# Processed download(250).png in 0.99 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(250)_widths.txt
# Processed download(251).png in 0.65 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(251)_widths.txt
# Processed download(252).png in 0.64 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(252)_widths.txt
# Processed download(253).png in 0.72 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(253)_widths.txt
# Processed download(254).png in 0.89 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(254)_widths.txt
# Processed download(255).png in 0.51 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(255)_widths.txt
# Processed download(256).png in 0.61 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(256)_widths.txt
# Processed download(257).png in 0.74 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(257)_widths.txt
# Processed download(258).png in 0.57 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(258)_widths.txt
# Processed download(259).png in 0.85 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(259)_widths.txt
# Processed download(260).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(260)_widths.txt
# Processed download(261).png in 0.56 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(261)_widths.txt
# Processed download(262).png in 0.74 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(262)_widths.txt
# Processed download(263).png in 0.66 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(263)_widths.txt
# Processed download(264).png in 0.70 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(264)_widths.txt
# Processed download(265).png in 0.58 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(265)_widths.txt
# Processed download(266).png in 0.50 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(266)_widths.txt
# Processed download(267).png in 0.52 seconds. Widths saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\download(267)_widths.txt
# Processing times saved to C:\Users\Paolo\OneDrive\Desktop\Thesis\Mycos_old_data (1)\Mycos_old_data\2014\20140415\width_extraction_after_SAM\processing_times_SAM.txt
